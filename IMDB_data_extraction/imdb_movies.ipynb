# %%
import pandas as pd
import numpy as np
from pandasql import sqldf

# %%
"""Data Cleaning movie list

1. Extract movies that are only classified as either short, movie or tv Movie.
2. Remove adult films
3. Replace '\\N' with 'NA' as that is considered missing.
4. Extract movies that started from 2000 to 2021
5. Remove isAdult and 'endYear' columns as those are irrelevant. """

# read in data downloaded from https://datasets.imdbws.com/
imdb_movies = pd.read_csv("title.basics.tsv", sep = '\t', low_memory=False)

imdb_titles = imdb_movies[(imdb_movies['titleType'] == 'movie') | \
						  (imdb_movies['titleType'] == 'tvMovie') | \
						  (imdb_movies['titleType'] == 'short')]
	

imdb_titles = imdb_titles[(imdb_titles['startYear'] >= '2000') & \
						  (imdb_titles['startYear'] <= '2021')]

imdb_titles = imdb_titles[imdb_titles['isAdult'] == '0']

imdb_titles = imdb_titles.replace(to_replace = '\\N', value = 'NA')

imdb_titles = imdb_titles.drop(['isAdult', 'endYear'], axis = 1)

# %%
imdb_titles
# Out:
#             tconst titleType                    primaryTitle  \
# 11059    tt0011216     movie                  Spanish Fiesta
# 11433    tt0011594     movie                 Pour don Carlos
# 11636    tt0011801     movie                Tötet nicht mehr
# 15179    tt0015414     movie          La tierra de los toros
# 33805    tt0034413     short              Youth Gets a Break
# ...            ...       ...                             ...
# 8650501  tt9916730     movie                          6 Gunn
# 8650511  tt9916754     movie  Chico Albuquerque - Revelações
# 8650512  tt9916756     short        Pretty Pretty Black Girl
# 8650516  tt9916764     short                              38
# 8650559  tt9916856     short                        The Wind
#
#                           originalTitle startYear runtimeMinutes        genres
# 11059                 La fête espagnole      2019             67         Drama
# 11433                   Pour don Carlos      2021             NA            NA
# 11636                  Tötet nicht mehr      2019             NA  Action,Crime
# 15179            La tierra de los toros      2000             60            NA
# 33805                Youth Gets a Break      2001             20         Short
# ...                                 ...       ...            ...           ...
# 8650501                          6 Gunn      2017            116            NA
# 8650511  Chico Albuquerque - Revelações      2013             49   Documentary
# 8650512        Pretty Pretty Black Girl      2019             NA         Short
# 8650516                              38      2018             NA         Short
# 8650559                        The Wind      2015             27         Short
#
# [950551 rows x 7 columns]

# %%
title_ratings = pd.read_csv("title.ratings.tsv", sep = '\t', low_memory=False)

# %%
pysqldf = lambda q: sqldf(q, globals()) # using SQL in python

# query to join the title table with the ratings table which has
# average IMDB rating and number of votes on the movie

q = """SELECT t.*, r.averageRating, r.numVotes
FROM imdb_titles t
LEFT JOIN title_ratings r
ON t.tconst = r.tconst
"""

# %%
movie_and_ratings = pysqldf(q)

# %%
movie_and_ratings
# Out:
#            tconst titleType                    primaryTitle  \
# 0       tt0011216     movie                  Spanish Fiesta
# 1       tt0011594     movie                 Pour don Carlos
# 2       tt0011801     movie                Tötet nicht mehr
# 3       tt0015414     movie          La tierra de los toros
# 4       tt0034413     short              Youth Gets a Break
# ...           ...       ...                             ...
# 950546  tt9916730     movie                          6 Gunn
# 950547  tt9916754     movie  Chico Albuquerque - Revelações
# 950548  tt9916756     short        Pretty Pretty Black Girl
# 950549  tt9916764     short                              38
# 950550  tt9916856     short                        The Wind
#
#                          originalTitle startYear runtimeMinutes        genres  \
# 0                    La fête espagnole      2019             67         Drama
# 1                      Pour don Carlos      2021             NA            NA
# 2                     Tötet nicht mehr      2019             NA  Action,Crime
# 3               La tierra de los toros      2000             60            NA
# 4                   Youth Gets a Break      2001             20         Short
# ...                                ...       ...            ...           ...
# 950546                          6 Gunn      2017            116            NA
# 950547  Chico Albuquerque - Revelações      2013             49   Documentary
# 950548        Pretty Pretty Black Girl      2019             NA         Short
# 950549                              38      2018             NA         Short
# 950550                        The Wind      2015             27         Short
#
#         averageRating  numVotes
# 0                 6.9      30.0
# 1                 5.9      21.0
# 2                 NaN       NaN
# 3                 5.3      15.0
# 4                 NaN       NaN
# ...               ...       ...
# 950546            NaN       NaN
# 950547            NaN       NaN
# 950548            NaN       NaN
# 950549            NaN       NaN
# 950550            NaN       NaN
#
# [950551 rows x 9 columns]

# %%
movie_and_ratings = movie_and_ratings.replace(np.nan, 0)

# %%
movie_and_ratings
# Out:
#            tconst titleType                    primaryTitle  \
# 0       tt0011216     movie                  Spanish Fiesta
# 1       tt0011594     movie                 Pour don Carlos
# 2       tt0011801     movie                Tötet nicht mehr
# 3       tt0015414     movie          La tierra de los toros
# 4       tt0034413     short              Youth Gets a Break
# ...           ...       ...                             ...
# 950546  tt9916730     movie                          6 Gunn
# 950547  tt9916754     movie  Chico Albuquerque - Revelações
# 950548  tt9916756     short        Pretty Pretty Black Girl
# 950549  tt9916764     short                              38
# 950550  tt9916856     short                        The Wind
#
#                          originalTitle startYear runtimeMinutes        genres  \
# 0                    La fête espagnole      2019             67         Drama
# 1                      Pour don Carlos      2021             NA            NA
# 2                     Tötet nicht mehr      2019             NA  Action,Crime
# 3               La tierra de los toros      2000             60            NA
# 4                   Youth Gets a Break      2001             20         Short
# ...                                ...       ...            ...           ...
# 950546                          6 Gunn      2017            116            NA
# 950547  Chico Albuquerque - Revelações      2013             49   Documentary
# 950548        Pretty Pretty Black Girl      2019             NA         Short
# 950549                              38      2018             NA         Short
# 950550                        The Wind      2015             27         Short
#
#         averageRating  numVotes
# 0                 6.9      30.0
# 1                 5.9      21.0
# 2                 0.0       0.0
# 3                 5.3      15.0
# 4                 0.0       0.0
# ...               ...       ...
# 950546            0.0       0.0
# 950547            0.0       0.0
# 950548            0.0       0.0
# 950549            0.0       0.0
# 950550            0.0       0.0
#
# [950551 rows x 9 columns]

# %%
movie_and_ratings = movie_and_ratings.replace(np.nan, 0)

# %%
movie_and_ratings
# Out:
#            tconst titleType                    primaryTitle  \
# 0       tt0011216     movie                  Spanish Fiesta
# 1       tt0011594     movie                 Pour don Carlos
# 2       tt0011801     movie                Tötet nicht mehr
# 3       tt0015414     movie          La tierra de los toros
# 4       tt0034413     short              Youth Gets a Break
# ...           ...       ...                             ...
# 950546  tt9916730     movie                          6 Gunn
# 950547  tt9916754     movie  Chico Albuquerque - Revelações
# 950548  tt9916756     short        Pretty Pretty Black Girl
# 950549  tt9916764     short                              38
# 950550  tt9916856     short                        The Wind
#
#                          originalTitle startYear runtimeMinutes        genres  \
# 0                    La fête espagnole      2019             67         Drama
# 1                      Pour don Carlos      2021             NA            NA
# 2                     Tötet nicht mehr      2019             NA  Action,Crime
# 3               La tierra de los toros      2000             60            NA
# 4                   Youth Gets a Break      2001             20         Short
# ...                                ...       ...            ...           ...
# 950546                          6 Gunn      2017            116            NA
# 950547  Chico Albuquerque - Revelações      2013             49   Documentary
# 950548        Pretty Pretty Black Girl      2019             NA         Short
# 950549                              38      2018             NA         Short
# 950550                        The Wind      2015             27         Short
#
#         averageRating  numVotes
# 0                 6.9      30.0
# 1                 5.9      21.0
# 2                 0.0       0.0
# 3                 5.3      15.0
# 4                 0.0       0.0
# ...               ...       ...
# 950546            0.0       0.0
# 950547            0.0       0.0
# 950548            0.0       0.0
# 950549            0.0       0.0
# 950550            0.0       0.0
#
# [950551 rows x 9 columns]

# %%
q2 = """SELECT t.*, r.averageRating, r.numVotes
FROM imdb_titles t
INNER JOIN title_ratings r
ON t.tconst = r.tconst"""
movie_and_ratings2 = pysqldf(q2)
movie_and_ratings2
# Out:
#            tconst titleType            primaryTitle  \
# 0       tt0011216     movie          Spanish Fiesta
# 1       tt0011594     movie         Pour don Carlos
# 2       tt0015414     movie  La tierra de los toros
# 3       tt0035423     movie          Kate & Leopold
# 4       tt0036177     movie      Muhomatsu no issho
# ...           ...       ...                     ...
# 277772  tt9916428     movie     The Secret of China
# 277773  tt9916460   tvMovie               Pink Taxi
# 277774  tt9916538     movie     Kuambil Lagi Hatiku
# 277775  tt9916544     short         My Sweet Prince
# 277776  tt9916720     short               The Nun 2
#
#                        originalTitle startYear runtimeMinutes  \
# 0                  La fête espagnole      2019             67
# 1                    Pour don Carlos      2021             NA
# 2             La tierra de los toros      2000             60
# 3                     Kate & Leopold      2001            118
# 4                 Muhomatsu no issho      2008            100
# ...                              ...       ...            ...
# 277772  Hong xing zhao yao Zhong guo      2019             NA
# 277773                     Pink Taxi      2019             NA
# 277774           Kuambil Lagi Hatiku      2019            123
# 277775               My Sweet Prince      2019             12
# 277776                     The Nun 2      2019             10
#
#                         genres  averageRating  numVotes
# 0                        Drama            6.9        30
# 1                           NA            5.9        21
# 2                           NA            5.3        15
# 3       Comedy,Fantasy,Romance            6.4     82687
# 4             Action,Adventure            7.3       118
# ...                        ...            ...       ...
# 277772   Adventure,History,War            3.8        14
# 277773                  Comedy            9.3        17
# 277774                   Drama            8.3         6
# 277775             Drama,Short            7.0        50
# 277776   Comedy,Horror,Mystery            5.4       178
#
# [277777 rows x 9 columns]
